# %%
import torch
from bubbleformer.models import get_model
from bubbleformer.data import BubblemlForecast

# %%
test_path = ["/share/crsp/lab/ai4ts/share/BubbleML_f32/PoolBoiling-Saturated-FC72-2D-0.1/Twall-92.hdf5"]
test_dataset = BubblemlForecast(
    filenames=test_path,
    fields=["dfun", "temperature", "velx", "vely"],
    norm="none",
    time_window=5,
    start_time=95
)

# %%
model_name = "avit_spatial_only"
model_kwargs = {
    "fields": 4,
    "time_window": 5,
    "patch_size": 16,
    "embed_dim": 384,
    "processor_blocks": 12,
    "num_heads": 6,
    "drop_path": 0.2,
}
model = get_model(model_name, **model_kwargs)

# %%
from collections import OrderedDict
weights_path = "/pub/sheikhh1/bubbleformer_logs/avit_spatial_only_poolboiling_saturated_36173273/hpc_ckpt_3.ckpt"
model_data = torch.load(weights_path, weights_only=False)
print(model_data.keys())
diff_term, div_term = model_data['hyper_parameters']['normalization_constants']
diff_term = torch.tensor(diff_term)
div_term = torch.tensor(div_term)
weight_state_dict = OrderedDict()
for key, val in model_data["state_dict"].items():
    name = key[6:]
    weight_state_dict[name] = val
del model_data
# Out:
# dict_keys(['epoch', 'global_step', 'pytorch-lightning_version', 'state_dict', 'loops', 'callbacks', 'optimizer_states', 'lr_schedulers', 'hparams_name', 'hyper_parameters'])

# %%
model.load_state_dict(weight_state_dict)
# Out:
# <All keys matched successfully>

# %%
from bubbleformer.utils.losses import LpLoss
_, _ = test_dataset.normalize(diff_term, div_term)
criterion = LpLoss(d=2, p=2, reduce_dims=[0,1], reductions=["mean", "mean"])
model.eval()
start_time = test_dataset.start_time
skip_itrs = test_dataset.time_window
model_preds = []
model_targets = []
timesteps = []
for itr in range(0, 500, skip_itrs):
    inp, tgt = test_dataset[itr]
    print(f"Autoreg pred {itr}, inp tw [{start_time+itr}, {start_time+itr+skip_itrs}], tgt tw [{start_time+itr+skip_itrs}, {start_time+itr+2*skip_itrs}]")
    if len(model_preds) > 0:
        inp = model_preds[-1] # T, C, H, W
    inp = inp.float().unsqueeze(0)
    pred = model(inp)
    pred = pred.squeeze(0).detach().cpu()
    tgt = tgt.detach().cpu()

    model_preds.append(pred)
    model_targets.append(tgt)
    timesteps.append(torch.arange(start_time+itr+skip_itrs, start_time+itr+2*skip_itrs))
    print(criterion(pred, tgt))
# Out:
# Autoreg pred 0, inp tw [95, 100], tgt tw [100, 105]
# tensor(0.0655)
# Autoreg pred 5, inp tw [100, 105], tgt tw [105, 110]
# tensor(0.1298)
# Autoreg pred 10, inp tw [105, 110], tgt tw [110, 115]
# tensor(0.1635)
# Autoreg pred 15, inp tw [110, 115], tgt tw [115, 120]
# tensor(0.2124)
# Autoreg pred 20, inp tw [115, 120], tgt tw [120, 125]
# tensor(0.2732)
# Autoreg pred 25, inp tw [120, 125], tgt tw [125, 130]
# tensor(0.3269)
# Autoreg pred 30, inp tw [125, 130], tgt tw [130, 135]
# tensor(0.3568)
# Autoreg pred 35, inp tw [130, 135], tgt tw [135, 140]
# tensor(0.3924)
# Autoreg pred 40, inp tw [135, 140], tgt tw [140, 145]
# tensor(0.4155)
# Autoreg pred 45, inp tw [140, 145], tgt tw [145, 150]
# tensor(0.4361)
# Autoreg pred 50, inp tw [145, 150], tgt tw [150, 155]
# tensor(0.4537)
# Autoreg pred 55, inp tw [150, 155], tgt tw [155, 160]
# tensor(0.4886)
# Autoreg pred 60, inp tw [155, 160], tgt tw [160, 165]
# tensor(0.5356)
# Autoreg pred 65, inp tw [160, 165], tgt tw [165, 170]
# tensor(0.5711)
# Autoreg pred 70, inp tw [165, 170], tgt tw [170, 175]
# tensor(0.5980)
# Autoreg pred 75, inp tw [170, 175], tgt tw [175, 180]
# tensor(0.6243)
# Autoreg pred 80, inp tw [175, 180], tgt tw [180, 185]
# tensor(0.6482)
# Autoreg pred 85, inp tw [180, 185], tgt tw [185, 190]
# tensor(0.6777)
# Autoreg pred 90, inp tw [185, 190], tgt tw [190, 195]
# tensor(0.7020)
# Autoreg pred 95, inp tw [190, 195], tgt tw [195, 200]
# tensor(0.7207)
# Autoreg pred 100, inp tw [195, 200], tgt tw [200, 205]
# tensor(0.7189)
# Autoreg pred 105, inp tw [200, 205], tgt tw [205, 210]
# tensor(0.7405)
# Autoreg pred 110, inp tw [205, 210], tgt tw [210, 215]
# tensor(0.7358)
# Autoreg pred 115, inp tw [210, 215], tgt tw [215, 220]
# tensor(0.7312)
# Autoreg pred 120, inp tw [215, 220], tgt tw [220, 225]
# tensor(0.7128)
# Autoreg pred 125, inp tw [220, 225], tgt tw [225, 230]
# tensor(0.6997)
# Autoreg pred 130, inp tw [225, 230], tgt tw [230, 235]
# tensor(0.6923)
# Autoreg pred 135, inp tw [230, 235], tgt tw [235, 240]
# tensor(0.7099)
# Autoreg pred 140, inp tw [235, 240], tgt tw [240, 245]
# tensor(0.7364)
# Autoreg pred 145, inp tw [240, 245], tgt tw [245, 250]
# tensor(0.7388)
# Autoreg pred 150, inp tw [245, 250], tgt tw [250, 255]
# tensor(0.7416)
# Autoreg pred 155, inp tw [250, 255], tgt tw [255, 260]
# tensor(0.7528)
# Autoreg pred 160, inp tw [255, 260], tgt tw [260, 265]
# tensor(0.7571)
# Autoreg pred 165, inp tw [260, 265], tgt tw [265, 270]
# tensor(0.7714)
# Autoreg pred 170, inp tw [265, 270], tgt tw [270, 275]
# tensor(0.7926)
# Autoreg pred 175, inp tw [270, 275], tgt tw [275, 280]
# tensor(0.8068)
# Autoreg pred 180, inp tw [275, 280], tgt tw [280, 285]
# tensor(0.8214)
# Autoreg pred 185, inp tw [280, 285], tgt tw [285, 290]
# tensor(0.8413)
# Autoreg pred 190, inp tw [285, 290], tgt tw [290, 295]
# tensor(0.8547)
# Autoreg pred 195, inp tw [290, 295], tgt tw [295, 300]
# tensor(0.8754)
# Autoreg pred 200, inp tw [295, 300], tgt tw [300, 305]
# tensor(0.8828)
# Autoreg pred 205, inp tw [300, 305], tgt tw [305, 310]
# tensor(0.8929)
# Autoreg pred 210, inp tw [305, 310], tgt tw [310, 315]
# tensor(0.8881)
# Autoreg pred 215, inp tw [310, 315], tgt tw [315, 320]
# tensor(0.8973)
# Autoreg pred 220, inp tw [315, 320], tgt tw [320, 325]
# tensor(0.9273)
# Autoreg pred 225, inp tw [320, 325], tgt tw [325, 330]
# tensor(0.9333)
# Autoreg pred 230, inp tw [325, 330], tgt tw [330, 335]
# tensor(0.9482)
# Autoreg pred 235, inp tw [330, 335], tgt tw [335, 340]
# tensor(0.9797)
# Autoreg pred 240, inp tw [335, 340], tgt tw [340, 345]
# tensor(1.0125)
# Autoreg pred 245, inp tw [340, 345], tgt tw [345, 350]
# tensor(1.0451)
# Autoreg pred 250, inp tw [345, 350], tgt tw [350, 355]
# tensor(1.0584)
# Autoreg pred 255, inp tw [350, 355], tgt tw [355, 360]
# tensor(1.0619)
# Autoreg pred 260, inp tw [355, 360], tgt tw [360, 365]
# tensor(1.0572)
# Autoreg pred 265, inp tw [360, 365], tgt tw [365, 370]
# tensor(1.0539)
# Autoreg pred 270, inp tw [365, 370], tgt tw [370, 375]
# tensor(1.0293)
# Autoreg pred 275, inp tw [370, 375], tgt tw [375, 380]
# tensor(0.9826)
# Autoreg pred 280, inp tw [375, 380], tgt tw [380, 385]
# tensor(0.9722)
# Autoreg pred 285, inp tw [380, 385], tgt tw [385, 390]
# tensor(0.9623)
# Autoreg pred 290, inp tw [385, 390], tgt tw [390, 395]
# tensor(0.9484)
# Autoreg pred 295, inp tw [390, 395], tgt tw [395, 400]
# tensor(0.9641)
# Autoreg pred 300, inp tw [395, 400], tgt tw [400, 405]
# tensor(0.9573)
# Autoreg pred 305, inp tw [400, 405], tgt tw [405, 410]
# tensor(0.9413)
# Autoreg pred 310, inp tw [405, 410], tgt tw [410, 415]
# tensor(0.9227)
# Autoreg pred 315, inp tw [410, 415], tgt tw [415, 420]
# tensor(0.9093)
# Autoreg pred 320, inp tw [415, 420], tgt tw [420, 425]
# tensor(0.8962)
# Autoreg pred 325, inp tw [420, 425], tgt tw [425, 430]
# tensor(0.8831)
# Autoreg pred 330, inp tw [425, 430], tgt tw [430, 435]
# tensor(0.8775)
# Autoreg pred 335, inp tw [430, 435], tgt tw [435, 440]
# tensor(0.9001)
# Autoreg pred 340, inp tw [435, 440], tgt tw [440, 445]
# tensor(0.9304)
# Autoreg pred 345, inp tw [440, 445], tgt tw [445, 450]
# tensor(0.9357)
# Autoreg pred 350, inp tw [445, 450], tgt tw [450, 455]
# tensor(0.9275)
# Autoreg pred 355, inp tw [450, 455], tgt tw [455, 460]
# tensor(0.9264)
# Autoreg pred 360, inp tw [455, 460], tgt tw [460, 465]
# tensor(0.9137)
# Autoreg pred 365, inp tw [460, 465], tgt tw [465, 470]
# tensor(0.9123)
# Autoreg pred 370, inp tw [465, 470], tgt tw [470, 475]
# tensor(0.9208)
# Autoreg pred 375, inp tw [470, 475], tgt tw [475, 480]
# tensor(0.9306)
# Autoreg pred 380, inp tw [475, 480], tgt tw [480, 485]
# tensor(0.9494)
# Autoreg pred 385, inp tw [480, 485], tgt tw [485, 490]
# tensor(0.9555)
# Autoreg pred 390, inp tw [485, 490], tgt tw [490, 495]
# tensor(0.9394)
# Autoreg pred 395, inp tw [490, 495], tgt tw [495, 500]
# tensor(0.9428)
# Autoreg pred 400, inp tw [495, 500], tgt tw [500, 505]
# tensor(0.9511)
# Autoreg pred 405, inp tw [500, 505], tgt tw [505, 510]
# tensor(0.9704)
# Autoreg pred 410, inp tw [505, 510], tgt tw [510, 515]
# tensor(0.9778)
# Autoreg pred 415, inp tw [510, 515], tgt tw [515, 520]
# tensor(0.9785)
# Autoreg pred 420, inp tw [515, 520], tgt tw [520, 525]
# tensor(0.9650)
# Autoreg pred 425, inp tw [520, 525], tgt tw [525, 530]
# tensor(0.9563)
# Autoreg pred 430, inp tw [525, 530], tgt tw [530, 535]
# tensor(0.9543)
# Autoreg pred 435, inp tw [530, 535], tgt tw [535, 540]
# tensor(0.9329)
# Autoreg pred 440, inp tw [535, 540], tgt tw [540, 545]
# tensor(0.9252)
# Autoreg pred 445, inp tw [540, 545], tgt tw [545, 550]
# tensor(0.9220)
# Autoreg pred 450, inp tw [545, 550], tgt tw [550, 555]
# tensor(0.9067)
# Autoreg pred 455, inp tw [550, 555], tgt tw [555, 560]
# tensor(0.9045)
# Autoreg pred 460, inp tw [555, 560], tgt tw [560, 565]
# tensor(0.9077)
# Autoreg pred 465, inp tw [560, 565], tgt tw [565, 570]
# tensor(0.8935)
# Autoreg pred 470, inp tw [565, 570], tgt tw [570, 575]
# tensor(0.8834)
# Autoreg pred 475, inp tw [570, 575], tgt tw [575, 580]
# tensor(0.8953)
# Autoreg pred 480, inp tw [575, 580], tgt tw [580, 585]
# tensor(0.8942)
# Autoreg pred 485, inp tw [580, 585], tgt tw [585, 590]
# tensor(0.8946)
# Autoreg pred 490, inp tw [585, 590], tgt tw [590, 595]
# tensor(0.8982)
# Autoreg pred 495, inp tw [590, 595], tgt tw [595, 600]
# tensor(0.9109)

# %%
from bubbleformer.utils.plot_utils import plot_bubbleml

model_preds = torch.cat(model_preds, dim=0)         # T, C, H, W
model_targets = torch.cat(model_targets, dim=0)     # T, C, H, W
timesteps = torch.cat(timesteps, dim=0)             # T,
num_var = len(test_dataset.fields)                  # C

preds = model_preds * div_term.view(1, num_var, 1, 1) + diff_term.view(1, num_var, 1, 1)     # denormalize
targets = model_targets * div_term.view(1, num_var, 1, 1) + diff_term.view(1, num_var, 1, 1) # denormalize

# %%
import os
save_dir = "/pub/sheikhh1/bubbleformer_logs/avit_spatial_only_poolboiling_saturated_36173273/epoch_200_outputs/sat_92"
os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, "predictions.pt")

torch.save({"preds": preds, "targets": targets, "timesteps": timesteps}, save_path)
plot_bubbleml(preds, targets, timesteps, save_dir)
# Out:
# 0 files done
# 25 files done
# 50 files done
# 75 files done
# 100 files done
# 125 files done
# 150 files done
# 175 files done
# 200 files done
# 225 files done
# 250 files done
# 275 files done
# 300 files done
# 325 files done
# 350 files done
# 375 files done
# 400 files done
# 425 files done
# 450 files done
# 475 files done

# %%
def get_eikonal_loss(phi):
    """
    phi = predicted sdf torch.Tensor(T,H,W)
    """
    dx = 1/32
    grad_x = (phi[:, :, 2:] - phi[:, :, :-2]) / (2 * dx)
    grad_y = (phi[:, 2:, :] - phi[:, :-2, :]) / (2 * dx)

    grad_x = torch.nn.functional.pad(grad_x, (1, 1), mode="replicate")
    grad_y = torch.nn.functional.pad(grad_y, (0, 0, 1, 1), mode="replicate")

    grad_magnitude = torch.sqrt(grad_x**2 + grad_y**2)
    loss_map = torch.abs(grad_magnitude - 1)
    mean_loss = torch.mean(loss_map, dim=(1, 2))
    return mean_loss

# %%
model_eikonal_loss = get_eikonal_loss(model_preds[:,0,:,:]).numpy()
sim_eikonal_loss = get_eikonal_loss(model_targets[:,0,:,:]).numpy()
timesteps = timesteps.numpy()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(timesteps, sim_eikonal_loss, label='Simulation Eikonal loss')
plt.plot(timesteps, model_eikonal_loss, label='Model Eikonal loss')
plt.xticks(np.arange(100, 600, 50))
plt.xlabel('Time')
plt.ylabel('Loss')
plt.title('Model vs Simulation sdf loss')
plt.legend()
